# %%
# Jupyter notebook

# on the command line, not within Jupyter
# pip3 install jupyter

# %%
x = 100             # press Enter == go down one line

print(f'x = {x}')   # press shift+enter == execute the cell
# Out:
# x = 100

# %%
x   #  the final expression in a cell has its value returned
# Out:
# 100

# %%
x*2
# Out:
# 200

# %%
x*2
# Out:
# 200

# %%
x = None   # None is a singleton
type(x)
# Out:
# NoneType

# %%
x = None
y = None

x == y      # not Pythonic!
# Out:
# True

# %%
x is y     # are x and y referencing the same object in memory?
# Out:
# True

# %%
# PEP 8 -- style guide for Python

# %%
x = 100
y = 100

x == y
# Out:
# True

# %%
x is y
# Out:
# True

# %%
x = 1000
y = 1000

x == y  # are the values of x and y the same?
# Out:
# True

# %%
x is y  # are x and y the same object in memory?
# Out:
# False

# %%
# "is" really compares object IDs
id(x) == id(y)
# Out:
# False

# %%
id(x)
# Out:
# 4615112176

# %%
s = 'abcd'
t = 'abcd'

s == t
# Out:
# True

# %%
s is t
# Out:
# True

# %%
s = 'abcd' * 2000
t = 'abcd' * 2000

s == t
# Out:
# True

# %%
s is t
# Out:
# False

# %%
s = 'a.b' 
t = 'a.b'

s == t
# Out:
# True

# %%
s is t
# Out:
# False

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# Jupyter notebook\n\n# on the command line, not within Jupyter\n# pip3 install jupyter',
#   "x = 100\n\nprint(f'x = {x}')",
#   "x = 100             # press Enter == go down one line\n\nprint(f'x = {x}')   # press shift+enter == ",
#   'x   #  the final expression in a cell has its value returned',
#   'x*2',
#   'x = None\ntype(x)',
#   'x = None\ny = None\n\nx == y   ',
#   'x = None\ny = None\n\nx == y      # not Pythonic!',
#   'x is y     # are x and y referencing the same object in memory?',
#   '# PEP 8 -- style guide for Python ',
#   'x = 100\ny = 100\n\nx == y',
#   'x is y',
#   'x = 1000\ny = 1000\n\nx == y',
#   'x is y',
#   'x is y  # are x and y the same object in memory?',
# ...

# %%
's' in globals()
# Out:
# True

# %%
globals()['s']
# Out:
# 'a.b'

# %%
# if a string looks like a valid Python identifier,
# we'll cache the string object and reuse it any time
# we see that string

# this is known as "interning"
# the  builtin "intern" function does it, if we want

from sys import intern
s = intern('a.b')  # means: either create a new string or get a cached one
t = intern('a.b')  # again, create or get a cached one

s is t
# Out:
# True

# %%
None == True
# Out:
# False

# %%
None == False
# Out:
# False

# %%
x = None
if x:  # force the object to be a boolean
    print("It is True-ish")
else:
    print("It is False-ish")
# Out:
# It is False-ish

# %%
# everything is True in a boolean context, except for:
# - None
# - False
# - 0 (of any type)
# - anything empty (empty string, empty list, etc.)

name = input("Enter your name: ")
# if name == '':  # not Pythonic!
if not name:      # whew!  Pythonic!
    print("Hey!  I wanted a name!")
else:
    print(f"Hello, {name}")
# Out:
# Enter your name:
# Hey!  I wanted a name!

# %%
x = 10000
x = x ** 100

# %%
x = x ** 100

# %%
type(x)
# Out:
# int

# %%
x
# Out:
# ...

# %%
s = '1234'
int(s)
# Out:
# 1234

# %%
# actually, s contains a hex number
int(s, 16)  # interpret it as base 16
# Out:
# 4660

# %%
id(int(s))
# Out:
# 4615111984

# %%
id(int(s))
# Out:
# 4615113936

# %%
id(int(s))
# Out:
# 4615113808

# %%
x = 10
y = 3

x * y
# Out:
# 30

# %%
x / y   # division in Python always returns a float!
# Out:
# 3.3333333333333335

# %%
# Python 3 has two types of division:
x / y   # truediv == returns a float
# Out:
# 3.3333333333333335

# %%
x // y    # floordiv == returns an int
# Out:
# 3

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %%
# BCD -- binary coded decimals
from decimal import Decimal

# %%
x = Decimal('0.1')
y = Decimal('0.2')

# %%
x + y
# Out:
# Decimal('0.3')

# %%
float(x+y)
# Out:
# 0.3

# %%
x = Decimal(0.1)
y = Decimal(0.2)

# %%
x
# Out:
# Decimal('0.1000000000000000055511151231257827021181583404541015625')

# %%
y
# Out:
# Decimal('0.200000000000000011102230246251565404236316680908203125')

# %%
path = 'c:\abc\def\ghi'
print(path)
# Out:
# c:bc\def\ghi

# %%
# \n == newline
# \t == tab
# \r == carriage return
# \t == vertical tab
# \a == alarm bell (control-G)

path = 'c:\\abc\\def\\ghi'
print(path)
# Out:
# c:\abc\def\ghi

# %%
path = r'c:\abc\def\ghi'  # raw string: double backslashes!
print(path)
# Out:
# c:\abc\def\ghi

# %%
s = """abc
defg
hijkl"""  # triple-quoted string

s
# Out:
# 'abc\ndefg\nhijkl'

# %%
x = 100
y = [10, 20, 30]
z = {'a':1, 'b':2}

# %%
# print("x is " + x + ' and y is ' + y + ', and z is ' + z)
print(f'x is {x}, and y is {y}, and z is {z}')
# Out:
# x is 100, and y is [10, 20, 30], and z is {'a': 1, 'b': 2}

# %%
first = 'Reuven'
last = 'Lerner'

print(f'Hello, {first:20} {last:20}.')
# Out:
# Hello, Reuven               Lerner              .

# %%
print(f'Hello, {first:_<20} {last:_^20}.')
# Out:
# Hello, Reuven______________ _______Lerner_______.

# %%
# Define a dict in which the keys are strings (1-4 characters long)
# and the values are integers (from 1-100,000).

# Iterate over the dict and print each key-value pair on a line
# by itself, such that the keys are flush left, the values are
# flush right, and there are . characters between them.

# a.....1
# bcd..10
# ef..123


d = {'a':1, 'bcd':10, 'ef':123}

for key in d:
    print(f'{key}: {d[key]}')
# Out:
# a: 1
# bcd: 10
# ef: 123

# %%
for key, value in d.items():
    print(f'{key:.<5}{value:.>5}')
# Out:
# a........1
# bcd.....10
# ef.....123

# %%
# regular strings: Unicode (UTF-8)
# byte strings: just bytes (no encoding at all)

s = 'hello'
s.encode()
# Out:
# b'hello'

# %%
type(s.encode())
# Out:
# bytes

# %%
b = s.encode()
b + b", Reuven"
# Out:
# b'hello, Reuven'

# %%
b.decode()
# Out:
# 'hello'

# %%
s = 'שלום'
len(s)
# Out:
# 4

# %%
b = s.encode()
b
# Out:
# b'\xd7\xa9\xd7\x9c\xd7\x95\xd7\x9d'

# %%
print(b)
# Out:
# b'\xd7\xa9\xd7\x9c\xd7\x95\xd7\x9d'

# %%
b.decode()
# Out:
# 'שלום'

# %%
mylist = [10, 20, 30]
len(mylist)
# Out:
# 3

# %%
# sequence is a string, list, or tuple
# - use len to get the length
# - use indexes [i]
# - use slices [start:finish ]  or [start:finish:stepsize]
# - iterable

# strings and tuples are immutable
# lists are mutable

# %%
mylist
# Out:
# [10, 20, 30]

# %%
mylist.append(40)
mylist
# Out:
# [10, 20, 30, 40]

# %%
import sys

mylist = []
for i in range(25):
    print(f'len(mylist) == {i}, size is {sys.getsizeof(mylist)}')
    mylist.append(i)
# Out:
# len(mylist) == 0, size is 72
# len(mylist) == 1, size is 104
# len(mylist) == 2, size is 104
# len(mylist) == 3, size is 104
# len(mylist) == 4, size is 104
# len(mylist) == 5, size is 136
# len(mylist) == 6, size is 136
# len(mylist) == 7, size is 136
# len(mylist) == 8, size is 136
# len(mylist) == 9, size is 200
# len(mylist) == 10, size is 200
# len(mylist) == 11, size is 200
# len(mylist) == 12, size is 200
# len(mylist) == 13, size is 200
# len(mylist) == 14, size is 200
# len(mylist) == 15, size is 200
# len(mylist) == 16, size is 200
# len(mylist) == 17, size is 272
# len(mylist) == 18, size is 272
# len(mylist) == 19, size is 272
# len(mylist) == 20, size is 272
# len(mylist) == 21, size is 272
# len(mylist) == 22, size is 272
# len(mylist) == 23, size is 272
# len(mylist) == 24, size is 272

# %%
sys.getsizeof(mylist)
# Out:
# 272

# %%
mylist[0] = 'abcd' * 1000000
sys.getsizeof(mylist)
# Out:
# 272

# %%
t = (10, 20, 30)
type(t)
# Out:
# tuple

# %%
t = (10, 20, 30)
type(t)
# Out:
# tuple

# %%
t = (10, 20)
type(t)
# Out:
# tuple

# %%
t = (10,)
type(t)
# Out:
# tuple

# %%
t = ()
type(t)
# Out:
# tuple

# %%
(2 + 3) * 4
# Out:
# 20

# %%
(2 + 3,) * 4
# Out:
# (5, 5, 5, 5)

# %%
t
# Out:
# (10,)

# %%
t = ([10, 20, 30], [100, 200, 300])
t[0]
# Out:
# [10, 20, 30]

# %%
t[0].append(40)
t
# Out:
# ([10, 20, 30, 40], [100, 200, 300])

# %%
t[0] += [50, 60, 70]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-2b735d214ecc> in <module>
# ----> 1 t[0] += [50, 60, 70]
#
# TypeError: 'tuple' object does not support item assignment

# %%
t
# Out:
# ([10, 20, 30, 40, 50, 60, 70], [100, 200, 300])

# %%
person = ('Reuven', 'Lerner', 46)
person[0]
# Out:
# 'Reuven'

# %%
person[1]
# Out:
# 'Lerner'

# %%
person[2]
# Out:
# 46

# %%
person = {'first':'Reuven', 'last':'Lerner', 'shoesize':46}
person['first']
# Out:
# 'Reuven'

# %%
person['last']
# Out:
# 'Lerner'

# %%
person['shoesize']
# Out:
# 46

# %%
# named tuples -- as efficient as tuples, and as readable as dicts
from collections import namedtuple

# %%
Person = namedtuple('Person', ['first', 'last', 'shoesize'])

# %%
type(Person)
# Out:
# type

# %%
Person.__name__
# Out:
# 'Person'

# %%
p = Person('Reuven', "Lerner", 46)
print(p)
# Out:
# Person(first='Reuven', last='Lerner', shoesize=46)

# %%
type(p)
# Out:
# __main__.Person

# %%
p.first
# Out:
# 'Reuven'

# %%
p.last
# Out:
# 'Lerner'

# %%
p.shoesize
# Out:
# 46

# %%
p.first = 'axdfdasdfasa'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-3c59b766dcf9> in <module>
# ----> 1 p.first = 'axdfdasdfasa'
#
# AttributeError: can't set attribute

# %%
p._replace(first='whatever')
# Out:
# Person(first='whatever', last='Lerner', shoesize=46)

# %%
d = {}
d['a'] = 1
d['b'] = 2

print(hash('a') % 8)  # new dicts have 8 slots
print(hash('b') % 8)
# Out:
# 7
# 1

# %%
'a' in d   # hash('a') -- check in that location
# Out:
# True

# %%
'a' in d  # hash('a') -> uses that to check in an array
          # if there's an array element there, it says where to look
          #   in the key-value table

# %%
d = {}
d['a'] = 1
d['b'] = 2
d['c'] = 3

for key in d:
    print(key)
# Out:
# a
# b
# c

# %%
d.pop('b') # remove key 'b' and return its value
# Out:
# 2

# %%
d['b'] = 200

for key in d:
    print(key)
# Out:
# a
# c
# b

# %%
mylist = [10, 20, 30]
d[mylist] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-432d8c226abb> in <module>
#       1 mylist = [10, 20, 30]
# ----> 2 d[mylist] = 100
#
# TypeError: unhashable type: 'list'

# %%
hash(mylist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-b5a9cdad35c5> in <module>
# ----> 1 hash(mylist)
#
# TypeError: unhashable type: 'list'

# %%
d
# Out:
# {'a': 1, 'c': 3, 'b': 200}

# %%
d.pop('c')
# Out:
# 3

# %%
d
# Out:
# {'a': 1, 'b': 200}

# %%
# find if a key is in the dict with "in"
'a' in d
# Out:
# True

# %%
'q' in d
# Out:
# False

# %%
# find a value, you need to use "in" on d.values()
# this is WAY WAY WAY slower!
200 in d.values()
# Out:
# True

# %%
while True:
    k = input("Enter a key: ")
    if not k:
        break
    elif k in d:
        print(f'd[{k}] == {d[k]}')
    else:
        print(f'{k} is not a key in d')
# Out:
# Enter a key: a
# d[a] == 1
# Enter a key: z
# z is not a key in d
# Enter a key:

# %%
d['z']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-bb37ae49ba54> in <module>
# ----> 1 d['z']
#
# KeyError: 'z'

# %%
# we can use the "get" method to safely retrieve from a dict
# it's like [], but if the key isn't there, we get None back

while True:
    k = input("Enter a key: ")
    if not k:
        break
        
    print(f'd[{k}] == {d.get(k)}')
# Out:
# Enter a key: a
# d[a] == 1
# Enter a key: b
# d[b] == 200
# Enter a key: c
# d[c] == None
# Enter a key:

# %%
# we can use the "get" method to safely retrieve from a dict
# it's like [], but if the key isn't there, we get None back

while True:
    k = input("Enter a key: ")
    if not k:
        break
        
    print(f'd[{k}] == {d.get(k, "(No such key)")}')
# Out:
# Enter a key: a
# d[a] == 1
# Enter a key: b
# d[b] == 200
# Enter a key: c
# d[c] == (No such key)
# Enter a key:

# %%
# setdefault -- adds a key-value pair to the dict
# but *ONLY* if the key is new!  

d
# Out:
# {'a': 1, 'b': 200}

# %%
d.setdefault('c', 300) # got 300 back -- so 'c':300 was added
# Out:
# 300

# %%
d.setdefault('c', 999) # got 300 back -- so 'c' was there, with 300
# Out:
# 300

# %%
# Use a dictionary to accumulate information about rainfall
# in various cities

# - ask the user to enter a city name
# - if they give a blank/empty name, stop asking
# - If they give a city, then ask for mm rain that fell there
# - store the rainfall in the dict where keys are city 
#   names, and values are mm rain
# - if the same city is entered twice, add to the current total

# City: Jerusalem
# Rain: 5
# City: Tel Aviv
# Rain: 4
# City: Tel Aviv
# Rain: 2
# City: <enter>
    
# Jerusalem: 5
# Tel Aviv: 6
    


while True:
    city_name = input("City: ").strip()
    if not city_name:
        break
        
    mm_rain = input("Rain: ").strip()

# %%
# set  -- just the "key" column in a dict
# that gets us:
# - very fast lookup
# - check for membership
# - guarantees uniqueness!

# %%
s = set([10, 20, 30, 10, 20, 30, 10, 20, 30])
s
# Out:
# {10, 20, 30}

# %%
s = {}   # empty set

type(s)
# Out:
# dict

# %%
s = set()  # use the word, to avoid problems

# %%
s = {10, 20, 30, 10, 20, 30, 10, 20, 30}
s
# Out:
# {10, 20, 30}

# %%
s.add(40)
len(s)
# Out:
# 4

# %%
s.add(40)
len(s)
# Out:
# 4

# %%
s.add(40)
len(s)
# Out:
# 4

# %%
s
# Out:
# {10, 20, 30, 40}

# %%
# add multiple items with set.update
s.update('abcd')  # gets an iterable, and adds them to the set
s
# Out:
# {10, 20, 30, 40, 'a', 'b', 'c', 'd'}

# %%
s1 = {1,2,3,4}
s2 = {3,4,5,6}

s1 | s2   # union -- returns a new set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1 & s2   # intersection -- returns a new set
# Out:
# {3, 4}

# %%
s1 ^ s2   # xor -- in one, but not both
# Out:
# {1, 2, 5, 6}

# %%
def dictdiff(first, second):
    output = {}
    for one_key in first.keys() | second.keys():
        v1 = first.get(one_key)
        v2 = second.get(one_key)
        
        if v1 != v2:
            output[one_key] = [v1, v2]
        
    return output

d1 = {'a': 1, 'b': 2, 'c': 3}
d2 = {'a': 1, 'b': 2, 'c': 4}

print(dictdiff(d1, d1))
# prints {}

print(dictdiff(d1, d2))
# # # # # # prints {'c': [3, 4]}

d1 = {'a': 1, 'b': 2, 'd': 3}
d2 = {'a': 1, 'b': 2, 'c': 4}

print(dictdiff(d1, d2))
# # # # # # prints {'c': [None, 4], 'd': [3, None]}

d1 = {'a': 1, 'b': 2, 'c': 3}
d2 = {'a': 1, 'b': 2, 'd': 4}

print(dictdiff(d1, d2))
# # # # prints {'c': [3, None], 'd': [None, 4]}
# Out:
# {}
# {'c': [3, 4]}
# {'c': [None, 4], 'd': [3, None]}
# {'c': [3, None], 'd': [None, 4]}

# %%
from collections import defaultdict

d = defaultdict(int)
print(d['a'])
print(d['b'])
d['a'] += 10
d['b'] += 20
print(d['a'])
print(d['b'])
# Out:
# 0
# 0
# 10
# 20

# %%
import time
time.time()
# Out:
# 1582541842.218431

# %%
d = defaultdict(time.time)

d['a']  # when did I request 'a' for the first time?
# Out:
# 1582541865.8698292

# %%
d['b']
# Out:
# 1582541869.292821

# %%
d
# Out:
# defaultdict(<function time.time>,
#             {'a': 1582541865.8698292, 'b': 1582541869.292821})

# %%
d = defaultdict(dict)

d['a']['b'] = 100
d['a']['bb'] = 150
d['c']['d'] = 200
d['c']['e'] = 300
d
# Out:
# defaultdict(dict, {'a': {'b': 100, 'bb': 150}, 'c': {'d': 200, 'e': 300}})

# %%
int()
# Out:
# 0

# %%
str()
# Out:
# ''

# %%
list()
# Out:
# []

# %%
dict()
# Out:
# {}

# %%
from collections import Counter

# %%
c = Counter()
c['a'] += 5
c['b'] += 3
c['a'] += 10
c['c'] += 20
c
# Out:
# Counter({'a': 15, 'b': 3, 'c': 20})

# %%
c = Counter([10, 20, 30, 20, 30, 40, 20, 30, 40, 50, 20, 30, 20, 30])
c
# Out:
# Counter({10: 1, 20: 5, 30: 5, 40: 2, 50: 1})

# %%
# pass Counter an iterable, and it'll count the number of times
# each element occurs in that iterable. 

words = 'this is a bunch of words and words are great and this is great'.split()
Counter(words)
# Out:
# Counter({'this': 2,
#          'is': 2,
#          'a': 1,
#          'bunch': 1,
#          'of': 1,
#          'words': 2,
#          'and': 2,
#          'are': 1,
#          'great': 2})

# %%
words = 'this is a bunch of words and words are great and this is great'
c = Counter(words)
c
# Out:
# Counter({'t': 4,
#          'h': 3,
#          'i': 4,
#          's': 6,
#          ' ': 13,
#          'a': 6,
#          'b': 1,
#          'u': 1,
#          'n': 3,
#          'c': 1,
#          'o': 3,
#          'f': 1,
#          'w': 2,
#          'r': 5,
#          'd': 4,
#          'e': 3,
#          'g': 2})

# %%
c.most_common(3)
# Out:
# [(' ', 13), ('s', 6), ('a', 6)]

# %%
c.most_common()
# Out:
# [(' ', 13),
#  ('s', 6),
#  ('a', 6),
#  ('r', 5),
#  ('t', 4),
#  ('i', 4),
#  ('d', 4),
#  ('h', 3),
#  ('n', 3),
#  ('o', 3),
#  ('e', 3),
#  ('w', 2),
#  ('g', 2),
#  ('b', 1),
#  ('u', 1),
#  ('c', 1),
#  ('f', 1)]

# %%
# list of lists
# list of tuples
# list of dicts
# dict of dicts

# %%
mylist = [10, 20, 30]
len(mylist)
# Out:
# 3

# %%
mylist = [[10, 20, 30], [40, 50, 60], [70, 80, 90] ]
len(mylist)
# Out:
# 3

# %%
mylist[2][1]  # mylist.__getitem__(2).__getitem__(1)
# Out:
# 80

# %%
mylist.__getitem__(2).__getitem__(1)
# Out:
# 80

# %%
s = 'abcd'
len(s)
# Out:
# 4

# %%
x = len(s)
x
# Out:
# 4

# %%
type(x)
# Out:
# int

# %%
x = s.upper() 
x
# Out:
# 'ABCD'

# %%
type(x)
# Out:
# str

# %%
x = s.upper

# %%
type(x)
# Out:
# builtin_function_or_method

# %%
x()
# Out:
# 'ABCD'

# %%
d = {'a':1, 'b':2, 'c':3}

for key, value in d.items():
    print(f'{key} : {value}')
# Out:
# a : 1
# b : 2
# c : 3

# %%
d = {'a':1, 'b':2, 'c':3}

for key, value in d.items:
    print(f'{key} : {value}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-216-36cde732958b> in <module>
#       1 d = {'a':1, 'b':2, 'c':3}
#       2
# ----> 3 for key, value in d.items:
#       4     print(f'{key} : {value}')
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
def hello():
    print("Hello!")

# %%
goodbye = hello

# %%
goodbye()
# Out:
# Hello!

# %%
x = hello()
# Out:
# Hello!

# %%
type(x)
# Out:
# NoneType

# %%
def hello():
    return "Hello!"

# %%
hello()
# Out:
# 'Hello!'

# %%
def hello(name):
    return f"Hello, {name}!"

# %%
hello('Reuven')
# Out:
# 'Hello, Reuven!'

# %%
hello('world')
# Out:
# 'Hello, world!'

# %%
hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-fbe3a7f7a563> in <module>
# ----> 1 hello()
#
# TypeError: hello() missing 1 required positional argument: 'name'

# %%
# two types of arguments in Python:
# - positional  -- based on their location in the arguments
# - keyword -- has to be in the format NAME=VALUE

# %%
def hello(name):
    return f"Hello, {name}!"

# %%
hello('world')
# Out:
# 'Hello, world!'

# %%
hello(5)
# Out:
# 'Hello, 5!'

# %%
hello([10, 20, 30])
# Out:
# 'Hello, [10, 20, 30]!'

# %%
hello(hello)
# Out:
# 'Hello, <function hello at 0x1141775f0>!'

# %%
# write a function "firstlast" that takes a string, list, or tuple
# of any length.

# it'll return the same data type with only two elements —
# taken from the first and last elements of the input.

# SO if I call:

def firstlast(data):
#    return data[:1] + data[-1:]
     return data[::len(data)-1]
    

print(firstlast('abcd'))  # 'ad'
print(firstlast([10, 20, 30, 40]))   # [10, 40]
print(firstlast((30, 50, 60, 70, 80)))  # (30, 80)
# Out:
# ad
# [10, 40]
# (30, 80)

# %%
def add(a, b):
    return a + b

add(10, 15)
# Out:
# 25

# %%
add(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-241-fb866b66e1c7> in <module>
# ----> 1 add(10)
#
# TypeError: add() missing 1 required positional argument: 'b'

# %%
add.__code__.co_argcount
# Out:
# 2

# %%
add.__code__.co_varnames
# Out:
# ('a', 'b')

# %%
add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-245-d5d29de3ed94> in <module>
# ----> 1 add()
#
# TypeError: add() missing 2 required positional arguments: 'a' and 'b'

# %%
add(b=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-246-9a126ae4859f> in <module>
# ----> 1 add(b=10)
#
# TypeError: add() missing 1 required positional argument: 'a'

# %%
def add(a, b=15):
    return a + b

add(10, 2)
# Out:
# 12

# %%
add(10)
# Out:
# 25

# %%
add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-249-d5d29de3ed94> in <module>
# ----> 1 add()
#
# TypeError: add() missing 1 required positional argument: 'a'

# %%
def add(a, b=15):
    return a + b

# %%
add.__defaults__
# Out:
# (15,)

# %%
add.__code__.co_argcount
# Out:
# 2

# %%
add(10)
# Out:
# 25

# %%
# does Python pass arguments by value or by reference?

# %%
del(x)

# %%
del(y)

# %%
x = 100

def foo(y):
    y = 200
    


# if it's call by reference, then x should be 200
# if it's call by value, then x should be 100

foo(x) 
x
# Out:
# 100

# %%
x = [10, 20, 30]

def add_one(y):
    y.append(1)
    
add_one(x)
x
# Out:
# [10, 20, 30, 1]

# %%
def add_one(y=[]):
    y.append(1)
    return y
    
x = [10, 20, 30]    
add_one(x)
x
# Out:
# [10, 20, 30, 1]

# %%
add_one(x)
# Out:
# [10, 20, 30, 1, 1]

# %%
x
# Out:
# [10, 20, 30, 1, 1]

# %%
add_one(x)
# Out:
# [10, 20, 30, 1, 1, 1]

# %%
add_one()
# Out:
# [1]

# %%
add_one()
# Out:
# [1, 1]

# %%
add_one()
# Out:
# [1, 1, 1]

# %%
def add_one(y=[]):
    y.append(1)
    return y

# %%
add_one.__defaults__
# Out:
# ([],)

# %%
add_one()
# Out:
# [1]

# %%
add_one.__defaults__
# Out:
# ([1],)

# %%
def mysum(numbers):
    total = 0
    for one_number in numbers:
        total += one_number
    return total

# %%
mysum([10, 20, 30])
# Out:
# 60

# %%
mysum([10, 20, 30, 40, 50])
# Out:
# 150

# %%
mysum(10, 20, 30, 40, 50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-279-bc0ae207bc6e> in <module>
# ----> 1 mysum(10, 20, 30, 40, 50)
#
# TypeError: mysum() takes 1 positional argument but 5 were given

# %%
def mysum(a=0, b=0, c=0, d=0, e=0, f=0, g=0):
    return a + b + c + d + e

mysum(10, 20, 30, 40, 50)
# Out:
# 150

# %%
mysum(10, 20, 30, 40, 50, 60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-281-fc81ec047e16> in <module>
# ----> 1 mysum(10, 20, 30, 40, 50, 60)
#
# TypeError: mysum() takes from 0 to 5 positional arguments but 6 were given

# %%
def mysum(*numbers):  # "splat-args" -- a tuple with all unclaimed args
    print(f'numbers = {numbers}')
    total = 0
    for one_number in numbers:
        total += one_number
    return total

# %%
mysum(10, 20, 30, 40, 50)
# Out:
# numbers = (10, 20, 30, 40, 50)
# 150

# %%
mysum(10, 20, 30)
# Out:
# numbers = (10, 20, 30)
# 60

# %%
mysum()
# Out:
# numbers = ()
# 0

# %%
mysum([10, 20, 30])
# Out:
# numbers = ([10, 20, 30],)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-286-d40f464f49d3> in <module>
# ----> 1 mysum([10, 20, 30])
#
# <ipython-input-282-d532a7787d33> in mysum(*numbers)
#       3     total = 0
#       4     for one_number in numbers:
# ----> 5         total += one_number
#       6     return total
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'

# %%
my_numbers = [10, 20, 30, 40, 50]

mysum(*my_numbers)  # unpack my_numbers to be many args
# Out:
# numbers = (10, 20, 30, 40, 50)
# 150

# %%
def add(a, b):
    return a + b

t = (2, 5)
add(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-289-f9a732914ade> in <module>
#       3
#       4 t = (2, 5)
# ----> 5 add(t)
#
# TypeError: add() missing 1 required positional argument: 'b'

# %%
add(*t) # call the function with *t, and unwind its args to be separate
# Out:
# 7

# %%
def foo(a, b, *args):
    print(f'a = {a}, b = {b}, args = {args}')

# %%
foo(10, 20, 30, 40, 50)
# Out:
# a = 10, b = 20, args = (30, 40, 50)

# %%
foo(10, 20)
# Out:
# a = 10, b = 20, args = ()

# %%
foo(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-297-3d16397afa9d> in <module>
# ----> 1 foo(10)
#
# TypeError: foo() missing 1 required positional argument: 'b'

# %%
foo.__code__.co_argcount
# Out:
# 2

# %%
foo.__code__.co_flags
# Out:
# 71

# %%
def foo(a, b, args):
    print(f'a = {a}, b = {b}, args = {args}')

# %%
foo.__code__.co_flags
# Out:
# 67

# %%
# bitflag of 4 == yes, it has *args

# %%
def foo(a, b, *args):
    print(f'a = {a}, b = {b}, args = {args}')
    
foo(10, 20, 30, 40, 50)

# %%
def foo(a, b=999, *args):
    print(f'a = {a}, b = {b}, args = {args}')
    
foo(10, 20, 30, 40, 50)
# Out:
# a = 10, b = 20, args = (30, 40, 50)

# %%
def foo(a, *args, b=999):
    print(f'a = {a}, b = {b}, args = {args}')
    
foo(10, 20, 30, 40, 50)
# Out:
# a = 10, b = 999, args = (20, 30, 40, 50)

# %%
foo(10, 20, 30, 40, 50, b=888)
# Out:
# a = 10, b = 888, args = (20, 30, 40, 50)

# %%
# write a function "all_lines"
# - mandatory argument for "filename", the name of the file
#   into which we'll write the output
# - any number of filenames after that, which will be our
#   inputs
# 
# write each line from the input files into the output file,
# prefacing each line with the file count and the line count
# (line count is specific to that file)

# [0][0] first line of first file
# [0][1] second line of first file
# [1][0] first line of second file

def all_lines(outfilename, *args):
    with open(outfilename, 'w') as outfile:
        for file_number, one_filename in enumerate(args):
            for line_number, one_line in enumerate(open(one_filename)):
                outfile.write(f'[{file_number:4}][{line_number:4}]{one_line}')

all_lines('output.txt', 
          '/etc/passwd', 
         '/Users/reuven/Consulting/LinuxJournal/articles/2018-12-pathlib.txt',
         '/Users/reuven/Consulting/LinuxJournal/articles/2019-04-mypy.txt')

# %%
# %cat output.txt
# Out:
# [   0][   0]##
# [   0][   1]# User Database
# [   0][   2]#
# [   0][   3]# Note that this file is consulted directly only when the system is running
# [   0][   4]# in single-user mode.  At other times this information is provided by
# [   0][   5]# Open Directory.
# [   0][   6]#
# [   0][   7]# See the opendirectoryd(8) man page for additional information about
# [   0][   8]# Open Directory.
# [   0][   9]##
# [   0][  10]nobody:*:-2:-2:Unprivileged User:/var/empty:/usr/bin/false
# [   0][  11]root:*:0:0:System Administrator:/var/root:/bin/sh
# [   0][  12]daemon:*:1:1:System Services:/var/root:/usr/bin/false
# [   0][  13]_uucp:*:4:4:Unix to Unix Copy Protocol:/var/spool/uucp:/usr/sbin/uucico
# [   0][  14]_taskgated:*:13:13:Task Gate Daemon:/var/empty:/usr/bin/false
# [   0][  15]_networkd:*:24:24:Network Services:/var/networkd:/usr/bin/false
# [   0][  16]_installassistant:*:25:25:Install Assistant:/var/empty:/usr/bin/false
# ...

# %%
d = {'a':1, 'b':2, 'c':3, 'd':4}

def show_names_and_values(d):
    for key, value in d.items():
        print(f'{key}: {value}')

# %%
show_names_and_values(d)
# Out:
# a: 1
# b: 2
# c: 3
# d: 4

# %%
# myfunc(name1=value1 name2=value2 name3=value3)

def show_names_and_values(**kwargs):  # d will be a dict!
    for key, value in kwargs.items():
        print(f'{key}: {value}')
        
show_names_and_values(a=1, b=2, c=3, d=4)
# Out:
# a: 1
# b: 2
# c: 3
# d: 4
